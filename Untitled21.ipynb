# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek12367/Laptop_Price_Prediction/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# read datasets as intsructed
train_df = pd.read_json("/content/test_dataset.json", orient="columns")
test_df = pd.read_json("/content/train_dataset.json", orient="columns")
val_df = pd.read_json("/content/val_dataset.json", orient="columns")

df = pd.concat([train_df, val_df, test_df], axis=0)
df.head(10)
# Out:
#         graphic card type                                     communications  \
# 5124   dedicated graphics                       [bluetooth, lan 10/100 mbps]
# 9595  integrated graphics  [bluetooth, lan 10/100/1000 mbps, lan 10/100 m...
# 4926   dedicated graphics           [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 2607  integrated graphics  [lan 10/100/1000 mbps, nfc (near field communi...
# 1185  integrated graphics                [wi-fi, bluetooth, lan 10/100 mbps]
# 6870  integrated graphics  [wi-fi, bluetooth, lan 10/100 mbps, modem 4g (...
# 7762  integrated graphics  [wi-fi 802.11 b/g/n/ac, bluetooth, lan 10/100/...
# 5449  integrated graphics                                               None
# 307   integrated graphics                [wi-fi, bluetooth, lan 10/100 mbps]
# 7151   dedicated graphics  [wi-fi, bluetooth, lan 10/100 mbps, intel wire...
#
#      resolution (px) CPU cores RAM size  \
# 5124     1920 x 1080         2     8 gb
# 9595     1920 x 1080         2     4 gb
# 4926     1920 x 1080         4    16 gb
# 2607     3200 x 1800         2     8 gb
# 1185      1366 x 768         2     4 gb
# 6870      1366 x 768         2     4 gb
# 7762     1920 x 1080         2     4 gb
# 5449      1366 x 768         2     4 gb
# 307       1366 x 768         4     6 gb
# 7151     1920 x 1080         2    16 gb
#
#                                        operating system drive type  \
# 5124                                  [windows 10 home]        hdd
# 9595                                  [windows 10 home]        ssd
# 4926                                  [windows 10 home]  ssd + hdd
# 2607                                  [windows 10 home]        ssd
# 1185                                  [windows 10 home]        hdd
# 6870  [windows 7 professional 64-bit, windows 10 pro...        hdd
# 7762                           [windows 10 home, other]        hdd
# 5449                                        [no system]        hdd
# 307                                   [windows 10 home]        ssd
# 7151                          [windows 10 professional]        hdd
#
#                                           input devices  \
# 5124                               [keyboard, touchpad]
# 9595                               [keyboard, touchpad]
# 4926  [keyboard, touchpad, illuminated keyboard, num...
# 2607                               [keyboard, touchpad]
# 1185             [keyboard, touchpad, numeric keyboard]
# 6870         [keyboard, touchpad, illuminated keyboard]
# 7762                               [keyboard, touchpad]
# 5449                                               None
# 307              [keyboard, touchpad, numeric keyboard]
# 7151         [keyboard, touchpad, illuminated keyboard]
#
#                                           multimedia RAM type  \
# 5124            [SD card reader, camera, microphone]     ddr4
# 9595            [SD card reader, camera, microphone]     ddr4
# 4926  [SD card reader, camera, speakers, microphone]     ddr4
# 2607                  [camera, speakers, microphone]    ddr3l
# 1185  [SD card reader, camera, speakers, microphone]     ddr3
# 6870                  [camera, speakers, microphone]     ddr4
# 7762          [SD card reader, speakers, microphone]     ddr3
# 5449                                            None     ddr4
# 307   [SD card reader, camera, speakers, microphone]     ddr3
# 7151  [SD card reader, camera, speakers, microphone]     ddr4
#
#       CPU clock speed (GHz)                CPU model state  \
# 5124                    2.0            intel core i3   new
# 9595                    2.0            intel core i3   new
# 4926                    2.8            intel core i7   new
# 2607                    NaN            intel core i5   new
# 1185                    1.6  intel celeron dual-core   new
# 6870                    2.4            intel core i5   new
# 7762                    2.0            intel core i3   new
# 5449                    2.0            intel core i3   new
# 307                     2.2            intel core i7   new
# 7151                    2.5            intel core i5   new
#
#       drive memory size (GB)           warranty  screen size  buynow_price
# 5124                  1000.0  producer warranty  15" - 15.9"       2369.00
# 9595                   240.0  producer warranty  15" - 15.9"       2299.00
# 4926                  1500.0  producer warranty  15" - 15.9"       5999.00
# 2607                   256.0  producer warranty  13" - 13.9"       3399.00
# 1185                   500.0  producer warranty  15" - 15.9"       1299.00
# 6870                   500.0  producer warranty  12" - 12.9"       3329.00
# 7762                  1000.0  producer warranty  15" - 15.9"       1749.00
# 5449                   500.0  producer warranty  15" - 15.9"       1549.00
# 307                    128.0    seller warranty  15" - 15.9"       2013.00
# 7151                  1000.0  producer warranty  14" - 14.9"       5103.19

# %%
df.dtypes
# Out:
# graphic card type          object
# communications             object
# resolution (px)            object
# CPU cores                  object
# RAM size                   object
# operating system           object
# drive type                 object
# input devices              object
# multimedia                 object
# RAM type                   object
# CPU clock speed (GHz)     float64
# CPU model                  object
# state                      object
# drive memory size (GB)    float64
# warranty                   object
# screen size                object
# buynow_price              float64
# dtype: object

# %%
# Look at unique values of each column, except the ones formatted as list
for col in df.columns.to_list():
    if type(df[col][0]) != list:
        print(f"unique values of {col} are: ", df[col].unique())
        print("-----------------------------------------------------")
# Out:
# unique values of graphic card type are:  ['dedicated graphics' 'integrated graphics' None]
# -----------------------------------------------------
# unique values of resolution (px) are:  ['1920 x 1080' '3200 x 1800' '1366 x 768' '1600 x 900' None '1920 x 1280'
#  '3840 x 2160' '2560 x 1440' '2160 x 1440' '1280 x 800' '1920 x 1200'
#  '2560 x 1600' 'other' '2880 x 1620']
# -----------------------------------------------------
# unique values of CPU cores are:  ['2' '4' 'not applicable' '8' '3' '1' '6']
# -----------------------------------------------------
# unique values of RAM size are:  ['8 gb' '4 gb' '16 gb' '6 gb' None '12 gb' '32 gb' '2 gb' '20 gb' '24 gb'
#  '256 mb' '64 gb']
# -----------------------------------------------------
# unique values of drive type are:  ['hdd' 'ssd' 'ssd + hdd' None 'emmc' 'hybrid']
# -----------------------------------------------------
# unique values of RAM type are:  ['ddr4' 'ddr3l' 'ddr3' None]
# -----------------------------------------------------
# unique values of CPU clock speed (GHz) are:  [2.   2.8   nan 1.6  2.4  2.2  2.5  2.3  2.1  1.9  2.7  1.8  2.6  1.7
#  2.13 2.16 1.1  1.35 1.4  1.83 2.9  1.3  1.   1.5  1.86 1.2  3.8  3.6
#  1.33 3.   0.   1.44 3.9  3.1  2.24 0.9  3.3  3.5  1.58 1.46 2.56 0.8
#  1.15 1.68 2.66 1.66]
# -----------------------------------------------------
# unique values of CPU model are:  ['intel core i3' 'intel core i7' 'intel core i5' 'intel celeron dual-core'
#  'intel pentium dual-core' 'amd a10' None 'amd a8' 'amd a12' 'other CPU'
#  'intel celeron ' 'amd a6' 'amd e1' 'intel celeron quad core '
#  'intel pentium quad-core ' 'amd a4' 'intel core m' 'intel pentium 4'
#  'intel celeron m']
# -----------------------------------------------------
# unique values of state are:  ['new']
# -----------------------------------------------------
# unique values of drive memory size (GB) are:  [1.000e+03 2.400e+02 1.500e+03 2.560e+02 5.000e+02 1.280e+02       nan
#  1.200e+02 2.512e+03 7.560e+02 4.800e+02 1.512e+03 1.120e+03 9.600e+02
#  1.128e+03 2.720e+02 1.250e+03 5.120e+02 1.240e+03 1.256e+03 3.200e+01
#  2.500e+02 2.256e+03 2.250e+03 2.000e+03 6.400e+01 7.500e+02 2.960e+03
#  7.680e+02 3.200e+02 1.024e+03 6.080e+02 1.480e+03 6.280e+02 1.000e+04
#  1.525e+03 2.128e+03 1.800e+02 1.628e+03 6.000e+01 1.275e+03 5.080e+02
#  1.600e+02 2.120e+03 2.750e+02 1.756e+03 5.250e+02 1.008e+03 1.728e+03
#  9.800e+02 2.500e+03 1.000e+00 3.680e+02 2.480e+03 6.800e+01 1.280e+03
#  1.920e+02 1.726e+03 5.240e+02 1.520e+02 1.012e+03 4.880e+02 8.000e+00
#  2.048e+03 0.000e+00 1.000e+02 9.900e+02 2.480e+02 4.960e+02 3.840e+02
#  7.400e+02 5.160e+02 3.640e+02]
# -----------------------------------------------------
# unique values of warranty are:  ['producer warranty' 'seller warranty' 'no warranty']
# -----------------------------------------------------
# unique values of screen size are:  ['15" - 15.9"' '13" - 13.9"' '12" - 12.9"' '14" - 14.9"' None
#  '17" - 17.9"' '11.9" and less']
# -----------------------------------------------------
# unique values of buynow_price are:  [2369.   2299.   5999.   ... 5178.   2314.23 2488.57]
# -----------------------------------------------------

# %% [markdown]
# State is only taking one values, So I am dropping it

# %%
df = df.drop(columns=['state'])
df = df.dropna()

# %% [markdown]
# Since columns like "Communications", "Multimedia","Input devices" has multiple values in single list and it is hard to represent them in numerical values

# %%
compact_cols = ['communications', 'input devices', 'multimedia']

# %%
pd.DataFrame(df['communications'].to_list())
# Out:
#               0                     1                     2  \
# 0     bluetooth       lan 10/100 mbps                  None
# 1     bluetooth  lan 10/100/1000 mbps       lan 10/100 mbps
# 2         wi-fi             bluetooth  lan 10/100/1000 mbps
# 3         wi-fi             bluetooth       lan 10/100 mbps
# 4         wi-fi             bluetooth       lan 10/100 mbps
# ...         ...                   ...                   ...
# 6104      wi-fi             bluetooth  lan 10/100/1000 mbps
# 6105  bluetooth       lan 10/100 mbps                  None
# 6106  bluetooth                  None                  None
# 6107      wi-fi             bluetooth                  None
# 6108  bluetooth  lan 10/100/1000 mbps                  None
#
#                                   3                               4  \
# 0                              None                            None
# 1     intel wireless display (widi)  nfc (near field communication)
# 2                              None                            None
# 3                              None                            None
# 4                    modem 4g (lte)                            None
# ...                             ...                             ...
# 6104                           None                            None
# 6105                           None                            None
# 6106                           None                            None
# 6107                           None                            None
# 6108                           None                            None
#
#                     5
# 0                None
# 1     modem 3g (wwan)
# 2                None
# 3                None
# 4                None
# ...               ...
# 6104             None
# 6105             None
# 6106             None
# 6107             None
# 6108             None
#
# [6109 rows x 6 columns]

# %%
def get_unique_vals(col_name):
    #to_list function splits each comma separated value to a new column
    col_df = pd.DataFrame(df[col_name].to_list())
    unique_vals = list()
    for col in col_df.columns.to_list():
        unique_vals += [val for val in list(col_df[col].unique()) if (val not in unique_vals and val is not None) ]

    return unique_vals

# %%
compact_dict = {col: [] for  col in compact_cols}

# apply get_unique_vals to all compact_cols
# search through the dataframe and add a feature to unique_vals list when it is not included before
for col in compact_cols:
    compact_dict[col] = get_unique_vals(col)

# %%
compact_dict
# Out:
# {'communications': ['bluetooth',
#   'wi-fi',
#   'wi-fi 802.11 b/g/n/ac',
#   'nfc (near field communication)',
#   'lan 10/100 mbps',
#   'wi-fi 802.11 a/b/g/n/ac',
#   'wi-fi 802.11 b/g/n',
#   'lan 10/100/1000 mbps',
#   'wi-fi 802.11 a/b/g/n',
#   'intel wireless display (widi)',
#   'gps',
#   'modem 4g (lte)',
#   'modem 3g (wwan)'],
#  'input devices': ['keyboard',
#   'touchpad',
#   'illuminated keyboard',
#   'numeric keyboard'],
#  'multimedia': ['SD card reader', 'camera', 'microphone', 'speakers']}

# %%
# transform string value to integer by excluding gb and mb
df['RAM size'] = df['RAM size'].str.replace(' gb','',regex=True)

# when regex=False, replace requires exact match
df['RAM size'] = df['RAM size'].str.replace('256 mb','0.256',regex=False)
df
# Out:
#          graphic card type                                     communications  \
# 5124    dedicated graphics                       [bluetooth, lan 10/100 mbps]
# 9595   integrated graphics  [bluetooth, lan 10/100/1000 mbps, lan 10/100 m...
# 4926    dedicated graphics           [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 1185   integrated graphics                [wi-fi, bluetooth, lan 10/100 mbps]
# 6870   integrated graphics  [wi-fi, bluetooth, lan 10/100 mbps, modem 4g (...
# ...                    ...                                                ...
# 2954   integrated graphics           [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 4816   integrated graphics                       [bluetooth, lan 10/100 mbps]
# 11249  integrated graphics                                        [bluetooth]
# 685    integrated graphics                                 [wi-fi, bluetooth]
# 2307    dedicated graphics                  [bluetooth, lan 10/100/1000 mbps]
#
#       resolution (px) CPU cores RAM size  \
# 5124      1920 x 1080         2        8
# 9595      1920 x 1080         2        4
# 4926      1920 x 1080         4       16
# 1185       1366 x 768         2        4
# 6870       1366 x 768         2        4
# ...               ...       ...      ...
# 2954       1366 x 768         4        6
# 4816      1920 x 1080         2        8
# 11249     1920 x 1080         2        4
# 685        1600 x 900         4        4
# 2307      1920 x 1080         2        8
#
#                                         operating system drive type  \
# 5124                                   [windows 10 home]        hdd
# 9595                                   [windows 10 home]        ssd
# 4926                                   [windows 10 home]  ssd + hdd
# 1185                                   [windows 10 home]        hdd
# 6870   [windows 7 professional 64-bit, windows 10 pro...        hdd
# ...                                                  ...        ...
# 2954                                   [windows 10 home]        ssd
# 4816                                         [no system]        ssd
# 11249                          [windows 10 professional]     hybrid
# 685                             [windows 10 home, other]        hdd
# 2307                                   [windows 10 home]        hdd
#
#                                            input devices  \
# 5124                                [keyboard, touchpad]
# 9595                                [keyboard, touchpad]
# 4926   [keyboard, touchpad, illuminated keyboard, num...
# 1185              [keyboard, touchpad, numeric keyboard]
# 6870          [keyboard, touchpad, illuminated keyboard]
# ...                                                  ...
# 2954              [keyboard, touchpad, numeric keyboard]
# 4816                                [keyboard, touchpad]
# 11249                               [keyboard, touchpad]
# 685                                 [keyboard, touchpad]
# 2307              [keyboard, touchpad, numeric keyboard]
#
#                                            multimedia RAM type  \
# 5124             [SD card reader, camera, microphone]     ddr4
# 9595             [SD card reader, camera, microphone]     ddr4
# 4926   [SD card reader, camera, speakers, microphone]     ddr4
# 1185   [SD card reader, camera, speakers, microphone]     ddr3
# 6870                   [camera, speakers, microphone]     ddr4
# ...                                               ...      ...
# 2954   [SD card reader, camera, speakers, microphone]     ddr3
# 4816               [SD card reader, camera, speakers]     ddr4
# 11249  [SD card reader, camera, speakers, microphone]     ddr3
# 685    [SD card reader, camera, speakers, microphone]     ddr3
# 2307   [SD card reader, camera, speakers, microphone]    ddr3l
#
#        CPU clock speed (GHz)                 CPU model  \
# 5124                    2.00             intel core i3
# 9595                    2.00             intel core i3
# 4926                    2.80             intel core i7
# 1185                    1.60   intel celeron dual-core
# 6870                    2.40             intel core i5
# ...                      ...                       ...
# 2954                    1.80                    amd a6
# 4816                    2.00             intel core i3
# 11249                   1.70             intel core i3
# 685                     1.86  intel celeron quad core
# 2307                    2.30             intel core i5
#
#        drive memory size (GB)           warranty  screen size  buynow_price
# 5124                   1000.0  producer warranty  15" - 15.9"       2369.00
# 9595                    240.0  producer warranty  15" - 15.9"       2299.00
# 4926                   1500.0  producer warranty  15" - 15.9"       5999.00
# 1185                    500.0  producer warranty  15" - 15.9"       1299.00
# 6870                    500.0  producer warranty  12" - 12.9"       3329.00
# ...                       ...                ...          ...           ...
# 2954                    256.0    seller warranty  15" - 15.9"       1699.00
# 4816                    480.0  producer warranty  15" - 15.9"       3171.00
# 11249                   500.0    seller warranty  12" - 12.9"       1859.24
# 685                    1000.0  producer warranty  17" - 17.9"       1299.00
# 2307                   1000.0  producer warranty  15" - 15.9"       2900.00
#
# [6109 rows x 16 columns]

# %% [markdown]
# The screen size is given in intervals and I am going to convert it into nearest integer

# %%
df['screen size'] = df['screen size'].apply(lambda x: int(str(x)[:2]))
df
# Out:
#          graphic card type                                     communications  \
# 5124    dedicated graphics                       [bluetooth, lan 10/100 mbps]
# 9595   integrated graphics  [bluetooth, lan 10/100/1000 mbps, lan 10/100 m...
# 4926    dedicated graphics           [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 1185   integrated graphics                [wi-fi, bluetooth, lan 10/100 mbps]
# 6870   integrated graphics  [wi-fi, bluetooth, lan 10/100 mbps, modem 4g (...
# ...                    ...                                                ...
# 2954   integrated graphics           [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 4816   integrated graphics                       [bluetooth, lan 10/100 mbps]
# 11249  integrated graphics                                        [bluetooth]
# 685    integrated graphics                                 [wi-fi, bluetooth]
# 2307    dedicated graphics                  [bluetooth, lan 10/100/1000 mbps]
#
#       resolution (px) CPU cores RAM size  \
# 5124      1920 x 1080         2        8
# 9595      1920 x 1080         2        4
# 4926      1920 x 1080         4       16
# 1185       1366 x 768         2        4
# 6870       1366 x 768         2        4
# ...               ...       ...      ...
# 2954       1366 x 768         4        6
# 4816      1920 x 1080         2        8
# 11249     1920 x 1080         2        4
# 685        1600 x 900         4        4
# 2307      1920 x 1080         2        8
#
#                                         operating system drive type  \
# 5124                                   [windows 10 home]        hdd
# 9595                                   [windows 10 home]        ssd
# 4926                                   [windows 10 home]  ssd + hdd
# 1185                                   [windows 10 home]        hdd
# 6870   [windows 7 professional 64-bit, windows 10 pro...        hdd
# ...                                                  ...        ...
# 2954                                   [windows 10 home]        ssd
# 4816                                         [no system]        ssd
# 11249                          [windows 10 professional]     hybrid
# 685                             [windows 10 home, other]        hdd
# 2307                                   [windows 10 home]        hdd
#
#                                            input devices  \
# 5124                                [keyboard, touchpad]
# 9595                                [keyboard, touchpad]
# 4926   [keyboard, touchpad, illuminated keyboard, num...
# 1185              [keyboard, touchpad, numeric keyboard]
# 6870          [keyboard, touchpad, illuminated keyboard]
# ...                                                  ...
# 2954              [keyboard, touchpad, numeric keyboard]
# 4816                                [keyboard, touchpad]
# 11249                               [keyboard, touchpad]
# 685                                 [keyboard, touchpad]
# 2307              [keyboard, touchpad, numeric keyboard]
#
#                                            multimedia RAM type  \
# 5124             [SD card reader, camera, microphone]     ddr4
# 9595             [SD card reader, camera, microphone]     ddr4
# 4926   [SD card reader, camera, speakers, microphone]     ddr4
# 1185   [SD card reader, camera, speakers, microphone]     ddr3
# 6870                   [camera, speakers, microphone]     ddr4
# ...                                               ...      ...
# 2954   [SD card reader, camera, speakers, microphone]     ddr3
# 4816               [SD card reader, camera, speakers]     ddr4
# 11249  [SD card reader, camera, speakers, microphone]     ddr3
# 685    [SD card reader, camera, speakers, microphone]     ddr3
# 2307   [SD card reader, camera, speakers, microphone]    ddr3l
#
#        CPU clock speed (GHz)                 CPU model  \
# 5124                    2.00             intel core i3
# 9595                    2.00             intel core i3
# 4926                    2.80             intel core i7
# 1185                    1.60   intel celeron dual-core
# 6870                    2.40             intel core i5
# ...                      ...                       ...
# 2954                    1.80                    amd a6
# 4816                    2.00             intel core i3
# 11249                   1.70             intel core i3
# 685                     1.86  intel celeron quad core
# 2307                    2.30             intel core i5
#
#        drive memory size (GB)           warranty  screen size  buynow_price
# 5124                   1000.0  producer warranty           15       2369.00
# 9595                    240.0  producer warranty           15       2299.00
# 4926                   1500.0  producer warranty           15       5999.00
# 1185                    500.0  producer warranty           15       1299.00
# 6870                    500.0  producer warranty           12       3329.00
# ...                       ...                ...          ...           ...
# 2954                    256.0    seller warranty           15       1699.00
# 4816                    480.0  producer warranty           15       3171.00
# 11249                   500.0    seller warranty           12       1859.24
# 685                    1000.0  producer warranty           17       1299.00
# 2307                   1000.0  producer warranty           15       2900.00
#
# [6109 rows x 16 columns]

# %% [markdown]
# Splitting 'resolution' column into two columns

# %%
df['resolution_x'] = df['resolution (px)'].apply(lambda x: x.split(' x ')[0]).astype(int)
df['resolution_y'] = df['resolution (px)'].apply(lambda x: x.split(' x ')[1]).astype(int)
df
# Out:
#          graphic card type                                     communications  \
# 5124    dedicated graphics                       [bluetooth, lan 10/100 mbps]
# 9595   integrated graphics  [bluetooth, lan 10/100/1000 mbps, lan 10/100 m...
# 4926    dedicated graphics           [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 1185   integrated graphics                [wi-fi, bluetooth, lan 10/100 mbps]
# 6870   integrated graphics  [wi-fi, bluetooth, lan 10/100 mbps, modem 4g (...
# ...                    ...                                                ...
# 2954   integrated graphics           [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 4816   integrated graphics                       [bluetooth, lan 10/100 mbps]
# 11249  integrated graphics                                        [bluetooth]
# 685    integrated graphics                                 [wi-fi, bluetooth]
# 2307    dedicated graphics                  [bluetooth, lan 10/100/1000 mbps]
#
#       resolution (px) CPU cores RAM size  \
# 5124      1920 x 1080         2        8
# 9595      1920 x 1080         2        4
# 4926      1920 x 1080         4       16
# 1185       1366 x 768         2        4
# 6870       1366 x 768         2        4
# ...               ...       ...      ...
# 2954       1366 x 768         4        6
# 4816      1920 x 1080         2        8
# 11249     1920 x 1080         2        4
# 685        1600 x 900         4        4
# 2307      1920 x 1080         2        8
#
#                                         operating system drive type  \
# 5124                                   [windows 10 home]        hdd
# 9595                                   [windows 10 home]        ssd
# 4926                                   [windows 10 home]  ssd + hdd
# 1185                                   [windows 10 home]        hdd
# 6870   [windows 7 professional 64-bit, windows 10 pro...        hdd
# ...                                                  ...        ...
# 2954                                   [windows 10 home]        ssd
# 4816                                         [no system]        ssd
# 11249                          [windows 10 professional]     hybrid
# 685                             [windows 10 home, other]        hdd
# 2307                                   [windows 10 home]        hdd
#
#                                            input devices  \
# 5124                                [keyboard, touchpad]
# 9595                                [keyboard, touchpad]
# 4926   [keyboard, touchpad, illuminated keyboard, num...
# 1185              [keyboard, touchpad, numeric keyboard]
# 6870          [keyboard, touchpad, illuminated keyboard]
# ...                                                  ...
# 2954              [keyboard, touchpad, numeric keyboard]
# 4816                                [keyboard, touchpad]
# 11249                               [keyboard, touchpad]
# 685                                 [keyboard, touchpad]
# 2307              [keyboard, touchpad, numeric keyboard]
#
#                                            multimedia RAM type  \
# 5124             [SD card reader, camera, microphone]     ddr4
# 9595             [SD card reader, camera, microphone]     ddr4
# 4926   [SD card reader, camera, speakers, microphone]     ddr4
# 1185   [SD card reader, camera, speakers, microphone]     ddr3
# 6870                   [camera, speakers, microphone]     ddr4
# ...                                               ...      ...
# 2954   [SD card reader, camera, speakers, microphone]     ddr3
# 4816               [SD card reader, camera, speakers]     ddr4
# 11249  [SD card reader, camera, speakers, microphone]     ddr3
# 685    [SD card reader, camera, speakers, microphone]     ddr3
# 2307   [SD card reader, camera, speakers, microphone]    ddr3l
#
#        CPU clock speed (GHz)                 CPU model  \
# 5124                    2.00             intel core i3
# 9595                    2.00             intel core i3
# 4926                    2.80             intel core i7
# 1185                    1.60   intel celeron dual-core
# 6870                    2.40             intel core i5
# ...                      ...                       ...
# 2954                    1.80                    amd a6
# 4816                    2.00             intel core i3
# 11249                   1.70             intel core i3
# 685                     1.86  intel celeron quad core
# 2307                    2.30             intel core i5
#
#        drive memory size (GB)           warranty  screen size  buynow_price  \
# 5124                   1000.0  producer warranty           15       2369.00
# 9595                    240.0  producer warranty           15       2299.00
# 4926                   1500.0  producer warranty           15       5999.00
# 1185                    500.0  producer warranty           15       1299.00
# 6870                    500.0  producer warranty           12       3329.00
# ...                       ...                ...          ...           ...
# 2954                    256.0    seller warranty           15       1699.00
# 4816                    480.0  producer warranty           15       3171.00
# 11249                   500.0    seller warranty           12       1859.24
# 685                    1000.0  producer warranty           17       1299.00
# 2307                   1000.0  producer warranty           15       2900.00
#
#        resolution_x  resolution_y
# 5124           1920          1080
# 9595           1920          1080
# 4926           1920          1080
# 1185           1366           768
# 6870           1366           768
# ...             ...           ...
# 2954           1366           768
# 4816           1920          1080
# 11249          1920          1080
# 685            1600           900
# 2307           1920          1080
#
# [6109 rows x 18 columns]

# %%
df = df.drop(columns=['resolution (px)'])

# %%
numerical_cols = ['CPU cores', 'RAM size', 'CPU clock speed (GHz)','drive memory size (GB)', 'screen size', 'resolution_x', 'resolution_y']
numerical_df = df[numerical_cols].astype(float)
numerical_df
# Out:
#        CPU cores  RAM size  CPU clock speed (GHz)  drive memory size (GB)  \
# 5124         2.0       8.0                   2.00                  1000.0
# 9595         2.0       4.0                   2.00                   240.0
# 4926         4.0      16.0                   2.80                  1500.0
# 1185         2.0       4.0                   1.60                   500.0
# 6870         2.0       4.0                   2.40                   500.0
# ...          ...       ...                    ...                     ...
# 2954         4.0       6.0                   1.80                   256.0
# 4816         2.0       8.0                   2.00                   480.0
# 11249        2.0       4.0                   1.70                   500.0
# 685          4.0       4.0                   1.86                  1000.0
# 2307         2.0       8.0                   2.30                  1000.0
#
#        screen size  resolution_x  resolution_y
# 5124          15.0        1920.0        1080.0
# 9595          15.0        1920.0        1080.0
# 4926          15.0        1920.0        1080.0
# 1185          15.0        1366.0         768.0
# 6870          12.0        1366.0         768.0
# ...            ...           ...           ...
# 2954          15.0        1366.0         768.0
# 4816          15.0        1920.0        1080.0
# 11249         12.0        1920.0        1080.0
# 685           17.0        1600.0         900.0
# 2307          15.0        1920.0        1080.0
#
# [6109 rows x 7 columns]

# %%
dummies_df = df['operating system'].str.join('|').str.get_dummies()
dummies_df
# Out:
#        no system  other  windows 10 home  windows 10 professional  \
# 5124           0      0                1                        0
# 9595           0      0                1                        0
# 4926           0      0                1                        0
# 1185           0      0                1                        0
# 6870           0      0                0                        1
# ...          ...    ...              ...                      ...
# 2954           0      0                1                        0
# 4816           1      0                0                        0
# 11249          0      0                0                        1
# 685            0      1                1                        0
# 2307           0      0                1                        0
#
#        windows 7 home 64-bit  windows 7 professional 32-bit  \
# 5124                       0                              0
# 9595                       0                              0
# 4926                       0                              0
# 1185                       0                              0
# 6870                       0                              0
# ...                      ...                            ...
# 2954                       0                              0
# 4816                       0                              0
# 11249                      0                              0
# 685                        0                              0
# 2307                       0                              0
#
#        windows 7 professional 64-bit  windows 8.1 home 32-bit  \
# 5124                               0                        0
# 9595                               0                        0
# 4926                               0                        0
# 1185                               0                        0
# 6870                               1                        0
# ...                              ...                      ...
# 2954                               0                        0
# 4816                               0                        0
# 11249                              0                        0
# 685                                0                        0
# 2307                               0                        0
#
#        windows 8.1 home 64-bit  windows 8.1 professional 32-bit  \
# 5124                         0                                0
# 9595                         0                                0
# 4926                         0                                0
# 1185                         0                                0
# 6870                         0                                0
# ...                        ...                              ...
# 2954                         0                                0
# 4816                         0                                0
# 11249                        0                                0
# 685                          0                                0
# 2307                         0                                0
#
#        windows 8.1 professional 64-bit
# 5124                                 0
# 9595                                 0
# 4926                                 0
# 1185                                 0
# 6870                                 0
# ...                                ...
# 2954                                 0
# 4816                                 0
# 11249                                0
# 685                                  0
# 2307                                 0
#
# [6109 rows x 11 columns]

# %%
dummy_cols = ['drive type', 'RAM type', 'CPU model']
for col in dummy_cols:
    col_dummies_df = df[col].str.get_dummies()
    dummies_df = pd.concat([dummies_df, col_dummies_df], axis=1)

dummies_df
# Out:
#        no system  other  windows 10 home  windows 10 professional  \
# 5124           0      0                1                        0
# 9595           0      0                1                        0
# 4926           0      0                1                        0
# 1185           0      0                1                        0
# 6870           0      0                0                        1
# ...          ...    ...              ...                      ...
# 2954           0      0                1                        0
# 4816           1      0                0                        0
# 11249          0      0                0                        1
# 685            0      1                1                        0
# 2307           0      0                1                        0
#
#        windows 7 home 64-bit  windows 7 professional 32-bit  \
# 5124                       0                              0
# 9595                       0                              0
# 4926                       0                              0
# 1185                       0                              0
# 6870                       0                              0
# ...                      ...                            ...
# 2954                       0                              0
# 4816                       0                              0
# 11249                      0                              0
# 685                        0                              0
# 2307                       0                              0
#
#        windows 7 professional 64-bit  windows 8.1 home 32-bit  \
# 5124                               0                        0
# 9595                               0                        0
# 4926                               0                        0
# 1185                               0                        0
# 6870                               1                        0
# ...                              ...                      ...
# 2954                               0                        0
# 4816                               0                        0
# 11249                              0                        0
# 685                                0                        0
# 2307                               0                        0
#
#        windows 8.1 home 64-bit  windows 8.1 professional 32-bit  ...  \
# 5124                         0                                0  ...
# 9595                         0                                0  ...
# 4926                         0                                0  ...
# 1185                         0                                0  ...
# 6870                         0                                0  ...
# ...                        ...                              ...  ...
# 2954                         0                                0  ...
# 4816                         0                                0  ...
# 11249                        0                                0  ...
# 685                          0                                0  ...
# 2307                         0                                0  ...
#
#        intel celeron dual-core  intel celeron m  intel celeron quad core   \
# 5124                         0                0                         0
# 9595                         0                0                         0
# 4926                         0                0                         0
# 1185                         1                0                         0
# 6870                         0                0                         0
# ...                        ...              ...                       ...
# 2954                         0                0                         0
# 4816                         0                0                         0
# 11249                        0                0                         0
# 685                          0                0                         1
# 2307                         0                0                         0
#
#        intel core i3  intel core i5  intel core i7  intel core m  \
# 5124               1              0              0             0
# 9595               1              0              0             0
# 4926               0              0              1             0
# 1185               0              0              0             0
# 6870               0              1              0             0
# ...              ...            ...            ...           ...
# 2954               0              0              0             0
# 4816               1              0              0             0
# 11249              1              0              0             0
# 685                0              0              0             0
# 2307               0              1              0             0
#
#        intel pentium dual-core  intel pentium quad-core   other CPU
# 5124                         0                         0          0
# 9595                         0                         0          0
# 4926                         0                         0          0
# 1185                         0                         0          0
# 6870                         0                         0          0
# ...                        ...                       ...        ...
# 2954                         0                         0          0
# 4816                         0                         0          0
# 11249                        0                         0          0
# 685                          0                         0          0
# 2307                         0                         0          0
#
# [6109 rows x 36 columns]

# %% [markdown]
# **Checking remaining columns**

# %%
label_col = ['buynow_price']
categorical_columns = [col for col in df.columns.to_list() if col not in compact_cols + label_col + numerical_cols + ['operating system'] + dummy_cols]
categorical_columns
# Out:
# ['graphic card type', 'warranty']

# %%
# encode them
categorical_df = pd.get_dummies(df[categorical_columns])
categorical_df
# Out:
#        graphic card type_dedicated graphics  \
# 5124                                   True
# 9595                                  False
# 4926                                   True
# 1185                                  False
# 6870                                  False
# ...                                     ...
# 2954                                  False
# 4816                                  False
# 11249                                 False
# 685                                   False
# 2307                                   True
#
#        graphic card type_integrated graphics  warranty_producer warranty  \
# 5124                                   False                        True
# 9595                                    True                        True
# 4926                                   False                        True
# 1185                                    True                        True
# 6870                                    True                        True
# ...                                      ...                         ...
# 2954                                    True                       False
# 4816                                    True                        True
# 11249                                   True                       False
# 685                                     True                        True
# 2307                                   False                        True
#
#        warranty_seller warranty
# 5124                      False
# 9595                      False
# 4926                      False
# 1185                      False
# 6870                      False
# ...                         ...
# 2954                       True
# 4816                      False
# 11249                      True
# 685                       False
# 2307                      False
#
# [6109 rows x 4 columns]

# %%
unique_cols = list()
for col in compact_cols:
    unique_cols += compact_dict[col]
compact_df = pd.DataFrame(columns = unique_cols , index=df.index, data=np.zeros((df.shape[0], len(unique_cols))))
compact_df
# Out:
#        bluetooth  wi-fi  wi-fi 802.11 b/g/n/ac  \
# 5124         0.0    0.0                    0.0
# 9595         0.0    0.0                    0.0
# 4926         0.0    0.0                    0.0
# 1185         0.0    0.0                    0.0
# 6870         0.0    0.0                    0.0
# ...          ...    ...                    ...
# 2954         0.0    0.0                    0.0
# 4816         0.0    0.0                    0.0
# 11249        0.0    0.0                    0.0
# 685          0.0    0.0                    0.0
# 2307         0.0    0.0                    0.0
#
#        nfc (near field communication)  lan 10/100 mbps  \
# 5124                              0.0              0.0
# 9595                              0.0              0.0
# 4926                              0.0              0.0
# 1185                              0.0              0.0
# 6870                              0.0              0.0
# ...                               ...              ...
# 2954                              0.0              0.0
# 4816                              0.0              0.0
# 11249                             0.0              0.0
# 685                               0.0              0.0
# 2307                              0.0              0.0
#
#        wi-fi 802.11 a/b/g/n/ac  wi-fi 802.11 b/g/n  lan 10/100/1000 mbps  \
# 5124                       0.0                 0.0                   0.0
# 9595                       0.0                 0.0                   0.0
# 4926                       0.0                 0.0                   0.0
# 1185                       0.0                 0.0                   0.0
# 6870                       0.0                 0.0                   0.0
# ...                        ...                 ...                   ...
# 2954                       0.0                 0.0                   0.0
# 4816                       0.0                 0.0                   0.0
# 11249                      0.0                 0.0                   0.0
# 685                        0.0                 0.0                   0.0
# 2307                       0.0                 0.0                   0.0
#
#        wi-fi 802.11 a/b/g/n  intel wireless display (widi)  ...  \
# 5124                    0.0                            0.0  ...
# 9595                    0.0                            0.0  ...
# 4926                    0.0                            0.0  ...
# 1185                    0.0                            0.0  ...
# 6870                    0.0                            0.0  ...
# ...                     ...                            ...  ...
# 2954                    0.0                            0.0  ...
# 4816                    0.0                            0.0  ...
# 11249                   0.0                            0.0  ...
# 685                     0.0                            0.0  ...
# 2307                    0.0                            0.0  ...
#
#        modem 4g (lte)  modem 3g (wwan)  keyboard  touchpad  \
# 5124              0.0              0.0       0.0       0.0
# 9595              0.0              0.0       0.0       0.0
# 4926              0.0              0.0       0.0       0.0
# 1185              0.0              0.0       0.0       0.0
# 6870              0.0              0.0       0.0       0.0
# ...               ...              ...       ...       ...
# 2954              0.0              0.0       0.0       0.0
# 4816              0.0              0.0       0.0       0.0
# 11249             0.0              0.0       0.0       0.0
# 685               0.0              0.0       0.0       0.0
# 2307              0.0              0.0       0.0       0.0
#
#        illuminated keyboard  numeric keyboard  SD card reader  camera  \
# 5124                    0.0               0.0             0.0     0.0
# 9595                    0.0               0.0             0.0     0.0
# 4926                    0.0               0.0             0.0     0.0
# 1185                    0.0               0.0             0.0     0.0
# 6870                    0.0               0.0             0.0     0.0
# ...                     ...               ...             ...     ...
# 2954                    0.0               0.0             0.0     0.0
# 4816                    0.0               0.0             0.0     0.0
# 11249                   0.0               0.0             0.0     0.0
# 685                     0.0               0.0             0.0     0.0
# 2307                    0.0               0.0             0.0     0.0
#
#        microphone  speakers
# 5124          0.0       0.0
# 9595          0.0       0.0
# 4926          0.0       0.0
# 1185          0.0       0.0
# 6870          0.0       0.0
# ...           ...       ...
# 2954          0.0       0.0
# 4816          0.0       0.0
# 11249         0.0       0.0
# 685           0.0       0.0
# 2307          0.0       0.0
#
# [6109 rows x 21 columns]

# %%
new_df = pd.concat([categorical_df, numerical_df, compact_df, dummies_df],axis=1)
new_df.head(5)
# Out:
#       graphic card type_dedicated graphics  \
# 5124                                  True
# 9595                                 False
# 4926                                  True
# 1185                                 False
# 6870                                 False
#
#       graphic card type_integrated graphics  warranty_producer warranty  \
# 5124                                  False                        True
# 9595                                   True                        True
# 4926                                  False                        True
# 1185                                   True                        True
# 6870                                   True                        True
#
#       warranty_seller warranty  CPU cores  RAM size  CPU clock speed (GHz)  \
# 5124                     False        2.0       8.0                    2.0
# 9595                     False        2.0       4.0                    2.0
# 4926                     False        4.0      16.0                    2.8
# 1185                     False        2.0       4.0                    1.6
# 6870                     False        2.0       4.0                    2.4
#
#       drive memory size (GB)  screen size  resolution_x  ...  \
# 5124                  1000.0         15.0        1920.0  ...
# 9595                   240.0         15.0        1920.0  ...
# 4926                  1500.0         15.0        1920.0  ...
# 1185                   500.0         15.0        1366.0  ...
# 6870                   500.0         12.0        1366.0  ...
#
#       intel celeron dual-core  intel celeron m  intel celeron quad core   \
# 5124                        0                0                         0
# 9595                        0                0                         0
# 4926                        0                0                         0
# 1185                        1                0                         0
# 6870                        0                0                         0
#
#       intel core i3  intel core i5  intel core i7  intel core m  \
# 5124              1              0              0             0
# 9595              1              0              0             0
# 4926              0              0              1             0
# 1185              0              0              0             0
# 6870              0              1              0             0
#
#       intel pentium dual-core  intel pentium quad-core   other CPU
# 5124                        0                         0          0
# 9595                        0                         0          0
# 4926                        0                         0          0
# 1185                        0                         0          0
# 6870                        0                         0          0
#
# [5 rows x 68 columns]

# %% [markdown]
# ##Multicollinearity Check##

# %% [markdown]
# Multicollinearity is a potential problem for this regression task. We will check it through Variance Inflation Factor (VIF). We will eliminate all features that have VIF score above 20. For each iteration, we will drop only one feature, since when the feature set is changed VIF scores also change.

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor

def compute_vif(features):
    # Select only numerical features
    numerical_features = new_df[features].select_dtypes(include=['number']).columns.tolist()

    vif_data = pd.DataFrame()
    vif_data["feature"] = numerical_features
    vif_data["VIF"] = [variance_inflation_factor(new_df[numerical_features].values, i)
                      for i in range(len(numerical_features))]
    return vif_data.sort_values(by=['VIF']).reset_index(drop=True)

features = new_df.columns.to_list()
vif_data = compute_vif(features)
vif_data
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                             feature       VIF
# 0             windows 7 home 64-bit  1.020567
# 1     windows 7 professional 32-bit  1.026360
# 2   windows 8.1 professional 32-bit  1.030101
# 3   windows 8.1 professional 64-bit  1.138242
# 4           windows 8.1 home 32-bit  1.286288
# ..                              ...       ...
# 59                 numeric keyboard       NaN
# 60                   SD card reader       NaN
# 61                           camera       NaN
# 62                       microphone       NaN
# 63                         speakers       NaN
#
# [64 rows x 2 columns]

# %%
# drop with highest vif score until all vif scores are under 20
multicollinearity = True

while multicollinearity:
    highest_vif_feature = vif_data['feature'].values.tolist()[-1]
    print("I will remove", highest_vif_feature)
    features.remove(highest_vif_feature)
    vif_data = compute_vif(features)
    multicollinearity = False if len(vif_data[vif_data.VIF > 20]) == 0 else True

selected_features = vif_data['feature'].values.tolist()
vif_data
# Out:
# I will remove speakers
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# I will remove microphone
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# I will remove camera
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# I will remove SD card reader
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# I will remove numeric keyboard
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# I will remove illuminated keyboard
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# I will remove touchpad
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# ...
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# I will remove wi-fi
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# I will remove bluetooth
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# I will remove other CPU
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# I will remove hybrid
# I will remove resolution_y
# I will remove ddr4
# I will remove screen size
# I will remove CPU clock speed (GHz)
# I will remove windows 10 home
# I will remove ssd
# I will remove resolution_x
#                             feature        VIF
# 0   windows 8.1 professional 32-bit   1.002054
# 1             windows 7 home 64-bit   1.006547
# 2   windows 8.1 professional 64-bit   1.006775
# 3     windows 7 professional 32-bit   1.009545
# 4           windows 8.1 home 32-bit   1.021237
# 5                   intel celeron m   1.026242
# 6                      intel core m   1.039658
# 7                            amd e1   1.062347
# 8                            amd a4   1.076571
# 9                           amd a10   1.100275
# 10                          amd a12   1.119046
# 11          windows 8.1 home 64-bit   1.182385
# 12         intel celeron quad core    1.189189
# 13                             emmc   1.231893
# 14                   intel celeron    1.258458
# 15                           amd a8   1.276279
# 16    windows 7 professional 64-bit   1.310201
# 17         intel pentium quad-core    1.383741
# 18                            other   1.407900
# 19          intel celeron dual-core   1.412809
# 20                            ddr3l   1.464689
# 21          windows 10 professional   1.466414
# 22                        no system   1.502928
# 23          intel pentium dual-core   1.705074
# 24                           amd a6   1.869489
# 25                             ddr3   2.133674
# 26                              hdd   2.852798
# 27                        ssd + hdd   3.197402
# 28                    intel core i3   3.353012
# 29                         RAM size   4.593739
# 30                    intel core i5   7.691973
# 31           drive memory size (GB)   8.327708
# 32                    intel core i7  10.190975
# 33                        CPU cores  18.344520

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# correlation matrix of multicollinearity free dataset
plt.figure(figsize=(20, 20)) # width and height in inches
corr_df = pd.concat([new_df[selected_features], df[label_col]], axis=1)
sns.heatmap(corr_df.corr(),annot=True, lw=1)
plt.show()

# %%
# use the indeces of given datasets to properly separate it again as initial datasets
train_indeces = train_df.dropna().index
val_indeces = val_df.dropna().index
test_indeces = test_df.dropna().index

# %%
train_df = new_df.loc[train_indeces]
val_df = new_df.loc[val_indeces]
test_df = new_df.loc[test_indeces]

# %%
# sklearn machine learning models expect y_train, y_test, y_val
# in the shape as (row_number, ) instead of (row_number, 1) shape, so apply .ravel()
X_train, X_val, X_test = train_df[selected_features].to_numpy(), val_df[selected_features].to_numpy(), test_df[selected_features].to_numpy()
y_train, y_val, y_test = df.loc[train_indeces][label_col].to_numpy().ravel(), df.loc[val_indeces][label_col].to_numpy().ravel(), df.loc[test_indeces][label_col].to_numpy().ravel()

# %%
X_train.shape
# Out:
# (1200, 34)

# %%
y_train.shape
# Out:
# (1200,)

# %% [markdown]
# ## Classical Machine Learning

# %% [markdown]
# We will implement and try different machine learning models from Linear Regression to Ensemble Methods. We will measure root-mean-squared-error as instructed. We will scale our data with MaxAbsScaler() from sklearn, which works well with sparse datasets.

# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import VotingRegressor
from sklearn import linear_model
from sklearn.neural_network import MLPRegressor

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, MaxAbsScaler

import matplotlib.pyplot as plt
from sklearn import tree
import seaborn as sns

def rmse(y_true, y_pred):
    # Calculate MSE and then take the square root to get RMSE
    mse = mean_squared_error(y_true, y_pred)  # Remove squared=False
    rmse_val = np.sqrt(mse)
    return rmse_val


def regression(regressor_name, regressor):
#     alternative scaler
#     pipe = make_pipeline(StandardScaler(), regressor)
    pipe = make_pipeline(MaxAbsScaler(), regressor)
    pipe.fit(X_train, y_train)
    predicted = pipe.predict(X_test)
    rmse_val = rmse(y_test, predicted)
    print(regressor_name, ':', rmse_val)
    pred_df[regressor_name+'_Pred'] = predicted
    plt.figure(regressor_name)
    plt.title(regressor_name)
    plt.xlabel('predicted')
    plt.ylabel('actual')
    sns.regplot(y=y_test,x=predicted)

regressors = {
    'Linear' : LinearRegression(),
    'MLP': MLPRegressor(random_state=42, max_iter=500, learning_rate="constant", learning_rate_init=0.6),
    'DecisionTree': DecisionTreeRegressor(max_depth=15, random_state=42),
    'RandomForest': RandomForestRegressor(random_state=42),
    'GradientBoosting': GradientBoostingRegressor(random_state=42, criterion='squared_error',
                                                  loss='squared_error',learning_rate=0.6, warm_start=True),
    'ExtraTrees': ExtraTreesRegressor(n_estimators=100, random_state=42),
}

pred_df = pd.DataFrame(columns =["Actual"])
pred_df["Actual"] = y_test

for key in regressors.keys():
    regression(key, regressors[key])
# Out:
# Linear : 945.6273799425722
# MLP : 941.0143147841612
# DecisionTree : 1010.4938983993508
# RandomForest : 874.0483147358937
# GradientBoosting : 846.7379921966698
# ExtraTrees : 938.4744939863511

# %% [markdown]
# # Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor

# classifiers
reg1 = regressors["GradientBoosting"]
reg2 = regressors["ExtraTrees"]
reg3 = regressors["RandomForest"]

# take the highest performed three models and combine them in a voting mechanism
# assign weights to their predictions and create new regressor
# it is possible to try with different weights
regression("Voting", VotingRegressor([("gb", reg1), ("et", reg2), ("rf", reg3)], weights=[0.4, 0.35, 0.25]))
# Out:
# Voting : 826.8416491404105

# %%
pred_df
# Out:
#        Actual  Linear_Pred     MLP_Pred  DecisionTree_Pred  RandomForest_Pred  \
# 0     4999.00  6261.570604  6324.954097        5740.666667        6539.632063
# 1     2649.00  4065.602543  3733.013314        2526.924286        2795.736612
# 2     4499.00  5029.801282  3748.137819        2078.990000        2782.710795
# 3     2099.00  2164.597005  2331.035396        2198.600000        2204.852264
# 4     2699.00  3013.753362  3188.681837        2699.000000        2838.793633
# ...       ...          ...          ...                ...                ...
# 3689  1699.00  1501.309369  1737.055933        1619.000000        1645.955025
# 3690  3171.00  2611.036321  2470.061803        2589.000000        2526.376905
# 3691  1859.24  2495.879862  2179.033117        1444.483750        2046.201812
# 3692  1299.00  1464.944426  1832.498778        3000.000000        1618.420000
# 3693  2900.00  2435.343895  2507.676371        2500.000000        2421.428750
#
#       GradientBoosting_Pred  ExtraTrees_Pred  Voting_Pred
# 0               7107.128812      6750.406667  6840.401874
# 1               3120.149716      2858.631686  2947.515129
# 2               3403.003667      2184.252700  2821.367610
# 3               2116.232601      2198.600000  2167.216106
# 4               2779.654680      2699.000000  2766.210280
# ...                     ...              ...          ...
# 3689            1485.974068      1632.000000  1577.078383
# 3690            2613.316182      2589.000000  2583.070699
# 3691            2349.176124      1855.122563  2100.513799
# 3692            1815.827155      2311.600000  1939.995862
# 3693            2156.870040      2500.000000  2343.105204
#
# [3694 rows x 8 columns]

# %% [markdown]
# ## Deep Learning

# %% [markdown]
# Another promising regression algorithm is artificial neural networks. We will create a small one with 4 hidden units since we have small data. We will use a scheduler to decrease the learning rate after a certain epoch number. Also, to prevent overfitting, we will use EarlyStopping.

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
import tensorflow.keras.backend as K

#from keras import backend as K
# set random for reproducibility
tf.random.set_seed(42)


# define the error metric using keras background
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# define learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 30:
        return lr
    else:
        return lr * tf.math.exp(-0.01)


# define base model architecture
def build_and_compile_base_model():
    model = keras.Sequential([
        layers.Normalization(axis=-1),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(4, activation='relu'),
        layers.Dense(1)
    ])

    model.compile(loss=root_mean_squared_error,
                optimizer=tf.keras.optimizers.Adam(0.005))
    model.build(input_shape=(None,len(selected_features)))
    return model

# define complex model architecture
def build_and_compile_complex_model():
    model = keras.Sequential([
        layers.Normalization(axis=-1),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(8, activation='relu'),
        layers.Dense(8, activation='relu'),
        layers.Dense(1)
    ])

    model.compile(loss=root_mean_squared_error,
                optimizer=tf.keras.optimizers.Adam(0.005))
    model.build(input_shape=(None,len(selected_features)))
    return model

# %%
# compile base model
dnn_model = build_and_compile_base_model()

# %%
dnn_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ normalization_2 (Normalization)      │ (None, 34)                  │              69 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 64)                  │           2,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 4)                   │             260 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,574 (10.06 KB)
#  Trainable params: 2,505 (9.79 KB)
#  Non-trainable params: 69 (280.00 B)

# %%
import tensorflow as tf

# Define learning rate scheduler function
def scheduler(epoch, lr):
    new_lr = 0.01 / (1 + 0.1 * epoch)  # Example decay
    print(f"Epoch {epoch}: Learning rate set to {new_lr}")  # Debugging output
    return float(new_lr)  # Convert explicitly to float

# Initialize scheduler and early stopping
scheduler_c = tf.keras.callbacks.LearningRateScheduler(scheduler)
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=20, restore_best_weights=True, verbose=1)

# Train the model
history = dnn_model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    callbacks=[scheduler_c, early_stopping],
    verbose=1,
    epochs=400
)
# Out:
# Epoch 0: Learning rate set to 0.01
# Epoch 1/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1273.2087 - val_loss: 1172.8485 - learning_rate: 0.0100
# Epoch 1: Learning rate set to 0.00909090909090909
# Epoch 2/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1241.9777 - val_loss: 1134.6614 - learning_rate: 0.0091
# Epoch 2: Learning rate set to 0.008333333333333333
# Epoch 3/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1221.2823 - val_loss: 1128.4563 - learning_rate: 0.0083
# Epoch 3: Learning rate set to 0.007692307692307692
# Epoch 4/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1214.3379 - val_loss: 1099.0898 - learning_rate: 0.0077
# Epoch 4: Learning rate set to 0.0071428571428571435
# Epoch 5/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1200.1713 - val_loss: 1086.3250 - learning_rate: 0.0071
# Epoch 5: Learning rate set to 0.006666666666666667
# Epoch 6/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1176.6755 - val_loss: 1077.6573 - learning_rate: 0.0067
# Epoch 6: Learning rate set to 0.0062499999999999995
# Epoch 7/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1197.6654 - val_loss: 1062.4852 - learning_rate: 0.0063
# Epoch 7: Learning rate set to 0.0058823529411764705
# Epoch 8/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1172.7329 - val_loss: 1053.2786 - learning_rate: 0.0059
# Epoch 8: Learning rate set to 0.005555555555555556
# Epoch 9/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1132.6244 - val_loss: 1041.6467 - learning_rate: 0.0056
# Epoch 9: Learning rate set to 0.005263157894736843
# Epoch 10/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1170.0764 - val_loss: 1034.1658 - learning_rate: 0.0053
# Epoch 10: Learning rate set to 0.005
# Epoch 11/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1153.0857 - val_loss: 1024.8837 - learning_rate: 0.0050
# Epoch 11: Learning rate set to 0.0047619047619047615
# Epoch 12/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1115.2747 - val_loss: 1022.0148 - learning_rate: 0.0048
# Epoch 12: Learning rate set to 0.004545454545454545
# Epoch 13/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1151.8864 - val_loss: 1014.5692 - learning_rate: 0.0045
# Epoch 13: Learning rate set to 0.004347826086956522
# Epoch 14/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1125.1677 - val_loss: 1007.8634 - learning_rate: 0.0043
# Epoch 14: Learning rate set to 0.004166666666666666
# Epoch 15/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1115.3037 - val_loss: 1000.9638 - learning_rate: 0.0042
# Epoch 15: Learning rate set to 0.004
# Epoch 16/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1098.8414 - val_loss: 1000.2956 - learning_rate: 0.0040
# Epoch 16: Learning rate set to 0.003846153846153846
# Epoch 17/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1091.7972 - val_loss: 993.5539 - learning_rate: 0.0038
# Epoch 17: Learning rate set to 0.0037037037037037034
# Epoch 18/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1114.0665 - val_loss: 985.1423 - learning_rate: 0.0037
# Epoch 18: Learning rate set to 0.0035714285714285718
# Epoch 19/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1134.7880 - val_loss: 981.4666 - learning_rate: 0.0036
# Epoch 19: Learning rate set to 0.003448275862068965
# Epoch 20/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1095.2855 - val_loss: 981.5008 - learning_rate: 0.0034
# Epoch 20: Learning rate set to 0.0033333333333333335
# Epoch 21/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1060.9039 - val_loss: 972.9484 - learning_rate: 0.0033
# Epoch 21: Learning rate set to 0.0032258064516129032
# Epoch 22/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1062.6196 - val_loss: 971.6955 - learning_rate: 0.0032
# Epoch 22: Learning rate set to 0.0031249999999999997
# Epoch 23/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1081.4498 - val_loss: 966.7642 - learning_rate: 0.0031
# Epoch 23: Learning rate set to 0.0030303030303030303
# Epoch 24/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1095.2473 - val_loss: 968.3454 - learning_rate: 0.0030
# Epoch 24: Learning rate set to 0.0029411764705882353
# Epoch 25/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1087.8096 - val_loss: 963.0460 - learning_rate: 0.0029
# Epoch 25: Learning rate set to 0.002857142857142857
# Epoch 26/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1115.9208 - val_loss: 958.4607 - learning_rate: 0.0029
# Epoch 26: Learning rate set to 0.002777777777777778
# Epoch 27/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1077.0654 - val_loss: 956.2068 - learning_rate: 0.0028
# Epoch 27: Learning rate set to 0.0027027027027027024
# Epoch 28/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1071.2877 - val_loss: 953.8950 - learning_rate: 0.0027
# Epoch 28: Learning rate set to 0.002631578947368421
# Epoch 29/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1088.5405 - val_loss: 955.9271 - learning_rate: 0.0026
# Epoch 29: Learning rate set to 0.002564102564102564
# Epoch 30/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1081.3920 - val_loss: 957.5786 - learning_rate: 0.0026
# Epoch 30: Learning rate set to 0.0025
# Epoch 31/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1060.5991 - val_loss: 948.3209 - learning_rate: 0.0025
# Epoch 31: Learning rate set to 0.002439024390243903
# Epoch 32/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1038.6000 - val_loss: 945.2575 - learning_rate: 0.0024
# Epoch 32: Learning rate set to 0.0023809523809523807
# Epoch 33/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1041.1245 - val_loss: 946.1571 - learning_rate: 0.0024
# Epoch 33: Learning rate set to 0.0023255813953488367
# Epoch 34/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1043.5955 - val_loss: 961.5142 - learning_rate: 0.0023
# Epoch 34: Learning rate set to 0.0022727272727272726
# Epoch 35/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1086.8452 - val_loss: 944.3438 - learning_rate: 0.0023
# Epoch 35: Learning rate set to 0.0022222222222222222
# Epoch 36/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1029.9089 - val_loss: 939.5090 - learning_rate: 0.0022
# Epoch 36: Learning rate set to 0.002173913043478261
# Epoch 37/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1040.6348 - val_loss: 938.5170 - learning_rate: 0.0022
# Epoch 37: Learning rate set to 0.002127659574468085
# Epoch 38/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1053.4858 - val_loss: 936.2833 - learning_rate: 0.0021
# Epoch 38: Learning rate set to 0.002083333333333333
# Epoch 39/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1072.9386 - val_loss: 936.3948 - learning_rate: 0.0021
# Epoch 39: Learning rate set to 0.002040816326530612
# Epoch 40/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1047.4210 - val_loss: 934.0546 - learning_rate: 0.0020
# Epoch 40: Learning rate set to 0.002
# Epoch 41/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1039.0760 - val_loss: 932.6993 - learning_rate: 0.0020
# Epoch 41: Learning rate set to 0.00196078431372549
# Epoch 42/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1039.4417 - val_loss: 931.1483 - learning_rate: 0.0020
# Epoch 42: Learning rate set to 0.001923076923076923
# Epoch 43/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1020.4162 - val_loss: 931.1049 - learning_rate: 0.0019
# Epoch 43: Learning rate set to 0.0018867924528301887
# Epoch 44/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1032.0883 - val_loss: 929.1561 - learning_rate: 0.0019
# Epoch 44: Learning rate set to 0.0018518518518518517
# Epoch 45/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1029.5880 - val_loss: 932.5557 - learning_rate: 0.0019
# Epoch 45: Learning rate set to 0.0018181818181818182
# Epoch 46/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1038.5264 - val_loss: 927.2548 - learning_rate: 0.0018
# Epoch 46: Learning rate set to 0.0017857142857142857
# Epoch 47/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1049.5477 - val_loss: 926.2460 - learning_rate: 0.0018
# Epoch 47: Learning rate set to 0.0017543859649122807
# Epoch 48/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1036.6783 - val_loss: 927.2256 - learning_rate: 0.0018
# Epoch 48: Learning rate set to 0.0017241379310344825
# Epoch 49/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1027.7506 - val_loss: 925.2796 - learning_rate: 0.0017
# Epoch 49: Learning rate set to 0.001694915254237288
# Epoch 50/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1013.6861 - val_loss: 924.2185 - learning_rate: 0.0017
# Epoch 50: Learning rate set to 0.0016666666666666668
# Epoch 51/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1036.6621 - val_loss: 923.8546 - learning_rate: 0.0017
# Epoch 51: Learning rate set to 0.001639344262295082
# Epoch 52/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1004.3492 - val_loss: 924.7737 - learning_rate: 0.0016
# Epoch 52: Learning rate set to 0.0016129032258064516
# Epoch 53/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1021.4904 - val_loss: 922.5147 - learning_rate: 0.0016
# Epoch 53: Learning rate set to 0.001587301587301587
# Epoch 54/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1021.2985 - val_loss: 922.3321 - learning_rate: 0.0016
# Epoch 54: Learning rate set to 0.0015624999999999999
# Epoch 55/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1021.7543 - val_loss: 923.2008 - learning_rate: 0.0016
# Epoch 55: Learning rate set to 0.0015384615384615385
# Epoch 56/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1012.2255 - val_loss: 921.0012 - learning_rate: 0.0015
# Epoch 56: Learning rate set to 0.0015151515151515152
# Epoch 57/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1038.2268 - val_loss: 919.0099 - learning_rate: 0.0015
# Epoch 57: Learning rate set to 0.0014925373134328358
# Epoch 58/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1036.0275 - val_loss: 918.9745 - learning_rate: 0.0015
# Epoch 58: Learning rate set to 0.0014705882352941176
# Epoch 59/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1028.1001 - val_loss: 920.4358 - learning_rate: 0.0015
# Epoch 59: Learning rate set to 0.0014492753623188406
# Epoch 60/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1030.3506 - val_loss: 918.5499 - learning_rate: 0.0014
# Epoch 60: Learning rate set to 0.0014285714285714286
# Epoch 61/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1032.0004 - val_loss: 916.9935 - learning_rate: 0.0014
# Epoch 61: Learning rate set to 0.001408450704225352
# Epoch 62/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1021.3467 - val_loss: 920.6487 - learning_rate: 0.0014
# Epoch 62: Learning rate set to 0.001388888888888889
# Epoch 63/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1002.2484 - val_loss: 917.5189 - learning_rate: 0.0014
# Epoch 63: Learning rate set to 0.00136986301369863
# Epoch 64/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1012.4579 - val_loss: 916.7416 - learning_rate: 0.0014
# Epoch 64: Learning rate set to 0.0013513513513513512
# Epoch 65/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1035.7954 - val_loss: 918.5900 - learning_rate: 0.0014
# Epoch 65: Learning rate set to 0.0013333333333333333
# Epoch 66/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1010.6571 - val_loss: 914.9858 - learning_rate: 0.0013
# Epoch 66: Learning rate set to 0.0013157894736842105
# Epoch 67/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1017.9148 - val_loss: 918.8504 - learning_rate: 0.0013
# Epoch 67: Learning rate set to 0.0012987012987012987
# Epoch 68/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1057.2621 - val_loss: 914.0259 - learning_rate: 0.0013
# Epoch 68: Learning rate set to 0.001282051282051282
# Epoch 69/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1040.8058 - val_loss: 913.8765 - learning_rate: 0.0013
# Epoch 69: Learning rate set to 0.0012658227848101266
# Epoch 70/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1032.9120 - val_loss: 912.7961 - learning_rate: 0.0013
# Epoch 70: Learning rate set to 0.00125
# Epoch 71/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1024.0215 - val_loss: 912.5846 - learning_rate: 0.0012
# Epoch 71: Learning rate set to 0.0012345679012345677
# Epoch 72/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1040.8032 - val_loss: 914.3921 - learning_rate: 0.0012
# Epoch 72: Learning rate set to 0.0012195121951219514
# Epoch 73/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1023.9066 - val_loss: 917.8637 - learning_rate: 0.0012
# Epoch 73: Learning rate set to 0.0012048192771084336
# Epoch 74/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1030.0322 - val_loss: 911.7600 - learning_rate: 0.0012
# Epoch 74: Learning rate set to 0.0011904761904761904
# Epoch 75/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1037.3206 - val_loss: 912.1385 - learning_rate: 0.0012
# Epoch 75: Learning rate set to 0.0011764705882352942
# Epoch 76/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1016.5475 - val_loss: 911.0719 - learning_rate: 0.0012
# Epoch 76: Learning rate set to 0.0011627906976744184
# Epoch 77/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 967.1110 - val_loss: 911.7653 - learning_rate: 0.0012
# Epoch 77: Learning rate set to 0.001149425287356322
# Epoch 78/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1011.0255 - val_loss: 910.0358 - learning_rate: 0.0011
# Epoch 78: Learning rate set to 0.0011363636363636363
# Epoch 79/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1036.9165 - val_loss: 909.6642 - learning_rate: 0.0011
# Epoch 79: Learning rate set to 0.0011235955056179774
# Epoch 80/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1012.9164 - val_loss: 909.5480 - learning_rate: 0.0011
# Epoch 80: Learning rate set to 0.0011111111111111111
# Epoch 81/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1042.9911 - val_loss: 909.6707 - learning_rate: 0.0011
# Epoch 81: Learning rate set to 0.001098901098901099
# Epoch 82/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1002.2010 - val_loss: 911.0008 - learning_rate: 0.0011
# Epoch 82: Learning rate set to 0.0010869565217391302
# Epoch 83/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1001.8247 - val_loss: 915.9916 - learning_rate: 0.0011
# Epoch 83: Learning rate set to 0.001075268817204301
# Epoch 84/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1029.6521 - val_loss: 909.8588 - learning_rate: 0.0011
# Epoch 84: Learning rate set to 0.0010638297872340426
# Epoch 85/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1019.5466 - val_loss: 910.4958 - learning_rate: 0.0011
# Epoch 85: Learning rate set to 0.0010526315789473684
# Epoch 86/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1022.8741 - val_loss: 908.4613 - learning_rate: 0.0011
# Epoch 86: Learning rate set to 0.0010416666666666667
# Epoch 87/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 992.2420 - val_loss: 908.6512 - learning_rate: 0.0010
# Epoch 87: Learning rate set to 0.0010309278350515462
# Epoch 88/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1043.0925 - val_loss: 908.7648 - learning_rate: 0.0010
# Epoch 88: Learning rate set to 0.001020408163265306
# Epoch 89/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1008.8543 - val_loss: 910.5863 - learning_rate: 0.0010
# Epoch 89: Learning rate set to 0.00101010101010101
# Epoch 90/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1009.2615 - val_loss: 908.2161 - learning_rate: 0.0010
# Epoch 90: Learning rate set to 0.001
# Epoch 91/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1027.8335 - val_loss: 907.0068 - learning_rate: 0.0010
# Epoch 91: Learning rate set to 0.0009900990099009901
# Epoch 92/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1002.5311 - val_loss: 911.3978 - learning_rate: 9.9010e-04
# Epoch 92: Learning rate set to 0.000980392156862745
# Epoch 93/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1031.2411 - val_loss: 906.9106 - learning_rate: 9.8039e-04
# Epoch 93: Learning rate set to 0.000970873786407767
# Epoch 94/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1000.2233 - val_loss: 908.7507 - learning_rate: 9.7087e-04
# Epoch 94: Learning rate set to 0.0009615384615384615
# Epoch 95/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1009.4702 - val_loss: 907.6723 - learning_rate: 9.6154e-04
# Epoch 95: Learning rate set to 0.0009523809523809524
# Epoch 96/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1006.7858 - val_loss: 911.4730 - learning_rate: 9.5238e-04
# Epoch 96: Learning rate set to 0.0009433962264150942
# Epoch 97/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1039.5013 - val_loss: 906.4212 - learning_rate: 9.4340e-04
# Epoch 97: Learning rate set to 0.0009345794392523364
# Epoch 98/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1016.4581 - val_loss: 910.3436 - learning_rate: 9.3458e-04
# Epoch 98: Learning rate set to 0.0009259259259259259
# Epoch 99/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1035.0742 - val_loss: 907.7617 - learning_rate: 9.2593e-04
# Epoch 99: Learning rate set to 0.0009174311926605504
# Epoch 100/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 991.0837 - val_loss: 913.5216 - learning_rate: 9.1743e-04
# Epoch 100: Learning rate set to 0.0009090909090909091
# Epoch 101/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1030.9493 - val_loss: 906.8447 - learning_rate: 9.0909e-04
# Epoch 101: Learning rate set to 0.0009009009009009008
# Epoch 102/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1022.2139 - val_loss: 904.9934 - learning_rate: 9.0090e-04
# Epoch 102: Learning rate set to 0.0008928571428571428
# Epoch 103/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1056.9082 - val_loss: 906.3924 - learning_rate: 8.9286e-04
# Epoch 103: Learning rate set to 0.0008849557522123894
# Epoch 104/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 967.9398 - val_loss: 909.4415 - learning_rate: 8.8496e-04
# Epoch 104: Learning rate set to 0.0008771929824561404
# Epoch 105/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1012.6700 - val_loss: 903.7900 - learning_rate: 8.7719e-04
# Epoch 105: Learning rate set to 0.0008695652173913044
# Epoch 106/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 982.9683 - val_loss: 906.5729 - learning_rate: 8.6957e-04
# Epoch 106: Learning rate set to 0.0008620689655172413
# Epoch 107/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1020.7656 - val_loss: 904.3182 - learning_rate: 8.6207e-04
# Epoch 107: Learning rate set to 0.0008547008547008546
# Epoch 108/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1021.7899 - val_loss: 903.0815 - learning_rate: 8.5470e-04
# Epoch 108: Learning rate set to 0.000847457627118644
# Epoch 109/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 978.2350 - val_loss: 908.9357 - learning_rate: 8.4746e-04
# Epoch 109: Learning rate set to 0.0008403361344537815
# Epoch 110/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1043.4628 - val_loss: 905.9230 - learning_rate: 8.4034e-04
# Epoch 110: Learning rate set to 0.0008333333333333334
# Epoch 111/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1002.5674 - val_loss: 903.7416 - learning_rate: 8.3333e-04
# Epoch 111: Learning rate set to 0.0008264462809917354
# Epoch 112/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1020.7374 - val_loss: 902.8093 - learning_rate: 8.2645e-04
# Epoch 112: Learning rate set to 0.000819672131147541
# Epoch 113/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 993.9352 - val_loss: 906.5811 - learning_rate: 8.1967e-04
# Epoch 113: Learning rate set to 0.0008130081300813008
# Epoch 114/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1013.5917 - val_loss: 903.9963 - learning_rate: 8.1301e-04
# Epoch 114: Learning rate set to 0.0008064516129032258
# Epoch 115/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 997.5749 - val_loss: 905.6589 - learning_rate: 8.0645e-04
# Epoch 115: Learning rate set to 0.0008
# Epoch 116/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1012.3281 - val_loss: 907.1780 - learning_rate: 8.0000e-04
# Epoch 116: Learning rate set to 0.0007936507936507935
# Epoch 117/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1020.1821 - val_loss: 901.9044 - learning_rate: 7.9365e-04
# Epoch 117: Learning rate set to 0.0007874015748031496
# Epoch 118/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1007.4948 - val_loss: 902.6601 - learning_rate: 7.8740e-04
# Epoch 118: Learning rate set to 0.0007812499999999999
# Epoch 119/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1004.6348 - val_loss: 902.3186 - learning_rate: 7.8125e-04
# Epoch 119: Learning rate set to 0.0007751937984496124
# Epoch 120/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1023.6129 - val_loss: 902.0049 - learning_rate: 7.7519e-04
# Epoch 120: Learning rate set to 0.0007692307692307692
# Epoch 121/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1018.2478 - val_loss: 902.3699 - learning_rate: 7.6923e-04
# Epoch 121: Learning rate set to 0.0007633587786259541
# Epoch 122/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1004.0982 - val_loss: 908.6001 - learning_rate: 7.6336e-04
# Epoch 122: Learning rate set to 0.0007575757575757576
# Epoch 123/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 992.9100 - val_loss: 911.3385 - learning_rate: 7.5758e-04
# Epoch 123: Learning rate set to 0.0007518796992481202
# Epoch 124/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 995.7610 - val_loss: 903.7081 - learning_rate: 7.5188e-04
# Epoch 124: Learning rate set to 0.0007462686567164179
# Epoch 125/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1004.6628 - val_loss: 907.5056 - learning_rate: 7.4627e-04
# Epoch 125: Learning rate set to 0.0007407407407407407
# Epoch 126/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 994.6406 - val_loss: 904.2471 - learning_rate: 7.4074e-04
# Epoch 126: Learning rate set to 0.0007352941176470588
# Epoch 127/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 986.1799 - val_loss: 903.2896 - learning_rate: 7.3529e-04
# Epoch 127: Learning rate set to 0.00072992700729927
# Epoch 128/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1002.9557 - val_loss: 902.8788 - learning_rate: 7.2993e-04
# Epoch 128: Learning rate set to 0.0007246376811594203
# Epoch 129/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 989.7717 - val_loss: 901.0825 - learning_rate: 7.2464e-04
# Epoch 129: Learning rate set to 0.0007194244604316547
# Epoch 130/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 978.6033 - val_loss: 905.8402 - learning_rate: 7.1942e-04
# Epoch 130: Learning rate set to 0.0007142857142857143
# Epoch 131/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 975.0660 - val_loss: 899.8911 - learning_rate: 7.1429e-04
# Epoch 131: Learning rate set to 0.0007092198581560283
# Epoch 132/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1014.7247 - val_loss: 902.1149 - learning_rate: 7.0922e-04
# Epoch 132: Learning rate set to 0.000704225352112676
# Epoch 133/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1006.2780 - val_loss: 902.2812 - learning_rate: 7.0423e-04
# Epoch 133: Learning rate set to 0.0006993006993006993
# Epoch 134/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1011.9810 - val_loss: 902.7728 - learning_rate: 6.9930e-04
# Epoch 134: Learning rate set to 0.0006944444444444445
# Epoch 135/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 984.4968 - val_loss: 906.7492 - learning_rate: 6.9444e-04
# Epoch 135: Learning rate set to 0.0006896551724137932
# Epoch 136/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1028.5446 - val_loss: 900.8625 - learning_rate: 6.8966e-04
# Epoch 136: Learning rate set to 0.000684931506849315
# Epoch 137/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1002.9793 - val_loss: 901.8936 - learning_rate: 6.8493e-04
# Epoch 137: Learning rate set to 0.0006802721088435374
# Epoch 138/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 993.8824 - val_loss: 901.9175 - learning_rate: 6.8027e-04
# Epoch 138: Learning rate set to 0.0006756756756756756
# Epoch 139/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 996.0992 - val_loss: 900.6453 - learning_rate: 6.7568e-04
# Epoch 139: Learning rate set to 0.0006711409395973154
# Epoch 140/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1017.6782 - val_loss: 899.0669 - learning_rate: 6.7114e-04
# Epoch 140: Learning rate set to 0.0006666666666666666
# Epoch 141/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 996.1226 - val_loss: 898.8138 - learning_rate: 6.6667e-04
# Epoch 141: Learning rate set to 0.0006622516556291391
# Epoch 142/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 981.4684 - val_loss: 904.1312 - learning_rate: 6.6225e-04
# Epoch 142: Learning rate set to 0.0006578947368421052
# Epoch 143/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1012.5739 - val_loss: 904.6021 - learning_rate: 6.5789e-04
# Epoch 143: Learning rate set to 0.00065359477124183
# Epoch 144/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1010.8737 - val_loss: 903.3597 - learning_rate: 6.5359e-04
# Epoch 144: Learning rate set to 0.0006493506493506494
# Epoch 145/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1023.5768 - val_loss: 901.7482 - learning_rate: 6.4935e-04
# Epoch 145: Learning rate set to 0.0006451612903225806
# Epoch 146/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1042.3722 - val_loss: 901.8528 - learning_rate: 6.4516e-04
# Epoch 146: Learning rate set to 0.000641025641025641
# Epoch 147/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 979.0804 - val_loss: 911.2485 - learning_rate: 6.4103e-04
# Epoch 147: Learning rate set to 0.0006369426751592356
# Epoch 148/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1003.2049 - val_loss: 901.6157 - learning_rate: 6.3694e-04
# Epoch 148: Learning rate set to 0.0006329113924050633
# Epoch 149/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1007.5418 - val_loss: 903.2210 - learning_rate: 6.3291e-04
# Epoch 149: Learning rate set to 0.0006289308176100629
# Epoch 150/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 973.2221 - val_loss: 901.1604 - learning_rate: 6.2893e-04
# Epoch 150: Learning rate set to 0.000625
# Epoch 151/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1007.1310 - val_loss: 900.9632 - learning_rate: 6.2500e-04
# Epoch 151: Learning rate set to 0.0006211180124223602
# Epoch 152/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 974.7708 - val_loss: 899.3248 - learning_rate: 6.2112e-04
# Epoch 152: Learning rate set to 0.0006172839506172838
# Epoch 153/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1010.3638 - val_loss: 900.6343 - learning_rate: 6.1728e-04
# Epoch 153: Learning rate set to 0.0006134969325153375
# Epoch 154/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 968.6224 - val_loss: 901.0322 - learning_rate: 6.1350e-04
# Epoch 154: Learning rate set to 0.0006097560975609757
# Epoch 155/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1010.5834 - val_loss: 904.2355 - learning_rate: 6.0976e-04
# Epoch 155: Learning rate set to 0.0006060606060606061
# Epoch 156/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1015.3567 - val_loss: 899.5899 - learning_rate: 6.0606e-04
# Epoch 156: Learning rate set to 0.0006024096385542168
# Epoch 157/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1018.5401 - val_loss: 902.0504 - learning_rate: 6.0241e-04
# Epoch 157: Learning rate set to 0.0005988023952095807
# Epoch 158/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1020.9174 - val_loss: 903.1277 - learning_rate: 5.9880e-04
# Epoch 158: Learning rate set to 0.0005952380952380952
# Epoch 159/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1004.3952 - val_loss: 899.5407 - learning_rate: 5.9524e-04
# Epoch 159: Learning rate set to 0.0005917159763313611
# Epoch 160/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1001.0192 - val_loss: 903.8454 - learning_rate: 5.9172e-04
# Epoch 160: Learning rate set to 0.0005882352941176471
# Epoch 161/400
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 994.4713 - val_loss: 901.2664 - learning_rate: 5.8824e-04
# Epoch 161: early stopping
# Restoring model weights from the end of the best epoch: 141.

# %%
import matplotlib.pyplot as plt

def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.ylim([0, 1200])
    plt.xlabel('Epoch')
    plt.ylabel('Error [Price]')
    plt.legend()
    plt.grid(True)

plot_loss(history)

# %%
# test model
dnn_model.evaluate(X_test, y_test, verbose=1)
# Out:
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 927.8327
# 933.4420776367188

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# Feature selection hurts the performance of this task. However, it is always best to present all the methods applied through the assignment. Hence, I am representing it also. We used f_regression and RandomForestRegressor.modelimportances to check feature importance. I decided on k=15, but you can change and see the results for different k values.

# %%
from sklearn.feature_selection import SelectKBest, f_regression
#Select top 25 features based on f-regression
selector = SelectKBest(f_regression, k =25)
X = new_df[selected_features].to_numpy()
y = df[label_col].to_numpy().ravel()
selector.fit(X, y)
cols = new_df[selected_features].columns[selector.get_support()].to_list()
cols
# Out:
# ['amd e1',
#  'amd a4',
#  'windows 8.1 home 64-bit',
#  'intel celeron quad core ',
#  'emmc',
#  'intel celeron ',
#  'amd a8',
#  'windows 7 professional 64-bit',
#  'intel pentium quad-core ',
#  'other',
#  'intel celeron dual-core',
#  'ddr3l',
#  'windows 10 professional',
#  'no system',
#  'intel pentium dual-core',
#  'amd a6',
#  'ddr3',
#  'hdd',
#  'ssd + hdd',
#  'intel core i3',
#  'RAM size',
#  'intel core i5',
#  'drive memory size (GB)',
#  'intel core i7',
#  'CPU cores']

# %%
X_train, X_val, X_test = train_df[cols].to_numpy(), val_df[cols].to_numpy(), test_df[cols].to_numpy()
y_train, y_val, y_test = df.loc[train_indeces][label_col].to_numpy().ravel(), df.loc[val_indeces][label_col].to_numpy().ravel(), df.loc[test_indeces][label_col].to_numpy().ravel()

# %%
regression('RandomForest', regressors['RandomForest'])
# Out:
# RandomForest : 857.1225769612045

# %%
X = new_df[selected_features].values
X_train, X_val, X_test = train_df[selected_features].to_numpy(), val_df[selected_features].to_numpy(), test_df[selected_features].to_numpy()
y_train, y_val, y_test = df.loc[train_indeces][label_col].to_numpy().ravel(), df.loc[val_indeces][label_col].to_numpy().ravel(), df.loc[test_indeces][label_col].to_numpy().ravel()
model = RandomForestRegressor(random_state=42)
# fit the model
model.fit(X_train, y_train)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print(f"Feature: {selected_features[i]} , Score: {v}")
# plot feature importance
plt.figure(figsize=(12, 9)) # width and height in inches
plt.bar(selected_features, importance)
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()
# Out:
# Feature: windows 8.1 professional 32-bit , Score: 0.0
# Feature: windows 7 home 64-bit , Score: 3.243212361033003e-05
# Feature: windows 8.1 professional 64-bit , Score: 0.00013052919286138376
# Feature: windows 7 professional 32-bit , Score: 1.9038541137728712e-05
# Feature: windows 8.1 home 32-bit , Score: 0.00012330826474017746
# Feature: intel celeron m , Score: 0.0
# Feature: intel core m , Score: 0.0
# Feature: amd e1 , Score: 0.0003438017751465885
# Feature: amd a4 , Score: 0.0004441120659879469
# Feature: amd a10 , Score: 5.406403626512205e-05
# Feature: amd a12 , Score: 0.000997582220251689
# Feature: windows 8.1 home 64-bit , Score: 0.0013971004254793664
# Feature: intel celeron quad core  , Score: 3.4505902659285855e-05
# Feature: emmc , Score: 0.0002608796598730293
# Feature: intel celeron  , Score: 0.0002944527027347054
# Feature: amd a8 , Score: 0.00013054770639529776
# Feature: windows 7 professional 64-bit , Score: 0.0015850503363718533
# Feature: intel pentium quad-core  , Score: 0.00021858449060473784
# Feature: other , Score: 0.002655619110938506
# Feature: intel celeron dual-core , Score: 0.0012903220996718346
# Feature: ddr3l , Score: 0.025900700809983652
# Feature: windows 10 professional , Score: 0.058456126805692996
# Feature: no system , Score: 0.01806214037418042
# Feature: intel pentium dual-core , Score: 0.002266752738972478
# Feature: amd a6 , Score: 0.004141495184374906
# Feature: ddr3 , Score: 0.10482206090812897
# Feature: hdd , Score: 0.03289836698108767
# Feature: ssd + hdd , Score: 0.010103563520544447
# Feature: intel core i3 , Score: 0.011424089119857267
# Feature: RAM size , Score: 0.22622576462097632
# Feature: intel core i5 , Score: 0.1086251417664217
# Feature: drive memory size (GB) , Score: 0.11701861897518923
# Feature: intel core i7 , Score: 0.1741423480905933
# Feature: CPU cores , Score: 0.095900899449267

# %%
feats_w_highest_importance = np.array(selected_features)[importance > 0.02].tolist()
feats_w_highest_importance
# Out:
# ['ddr3l',
#  'windows 10 professional',
#  'ddr3',
#  'hdd',
#  'RAM size',
#  'intel core i5',
#  'drive memory size (GB)',
#  'intel core i7',
#  'CPU cores']

# %%
X_train, X_val, X_test = train_df[feats_w_highest_importance].to_numpy(), val_df[feats_w_highest_importance].to_numpy(), test_df[feats_w_highest_importance].to_numpy()
y_train, y_val, y_test = df.loc[train_indeces][label_col].to_numpy().ravel(), df.loc[val_indeces][label_col].to_numpy().ravel(), df.loc[test_indeces][label_col].to_numpy().ravel()

# %%
regression('RandomForest', regressors['RandomForest'])
# Out:
# RandomForest : 874.0483147358937
